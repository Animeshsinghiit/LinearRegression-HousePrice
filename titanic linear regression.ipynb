# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
data=pd.read_csv("train.csv")
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
housep=pd.concat([data.LotArea,data.SalePrice], axis="columns")

# %%
housep.head()
# Out:
#    LotArea  SalePrice
# 0     8450     208500
# 1     9600     181500
# 2    11250     223500
# 3     9550     140000
# 4    14260     250000

# %%
# %matplotlib inline
plt.scatter(housep.LotArea,housep.SalePrice, color="red",marker="*")
plt.xlabel("Area")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(housep[["LotArea"]],housep.SalePrice)
# Out:
# LinearRegression()

# %%
reg.predict([[3245]])
# Out:
# /home/mrnalayk/anaconda3/lib/python3.8/site-packages/sklearn/base.py:445: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([165650.56088017])

# %%
tdata=pd.read_csv("test.csv")
tdata.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
test=pd.DataFrame(tdata.LotArea)
t1=test.head()

# %%
t1
# Out:
#    LotArea
# 0    11622
# 1    14267
# 2    13830
# 3     9978
# 4     5005

# %%
# test["SalePrice"]=""
pred=[]
for i in test.LotArea:
    pred.append(reg.predict([[i]]))
# Out:
# /home/mrnalayk/anaconda3/lib/python3.8/site-packages/sklearn/base.py:445: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /home/mrnalayk/anaconda3/lib/python3.8/site-packages/sklearn/base.py:445: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /home/mrnalayk/anaconda3/lib/python3.8/site-packages/sklearn/base.py:445: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /home/mrnalayk/anaconda3/lib/python3.8/site-packages/sklearn/base.py:445: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /home/mrnalayk/anaconda3/lib/python3.8/site-packages/sklearn/base.py:445: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ...

# %%
predD=pd.DataFrame(pred)

# %%
predD.head()
# Out:
#                0
# 0  183242.025920
# 1  188796.451732
# 2  187878.763989
# 3  179789.672031
# 4  169346.511515

# %%
final=pd.concat([test,predD],axis="columns")

# %%
final.head()
# Out:
#    LotArea SalePrice              0
# 0    11622            183242.025920
# 1    14267            188796.451732
# 2    13830            187878.763989
# 3     9978            179789.672031
# 4     5005            169346.511515

# %%
final["SalePrice"]=final[0]

# %%
final.head()
# Out:
#    LotArea      SalePrice              0
# 0    11622  183242.025920  183242.025920
# 1    14267  188796.451732  188796.451732
# 2    13830  187878.763989  187878.763989
# 3     9978  179789.672031  179789.672031
# 4     5005  169346.511515  169346.511515

# %%
main=final.drop(0,axis="columns")

# %%
main.head()
# Out:
#    LotArea      SalePrice
# 0    11622  183242.025920
# 1    14267  188796.451732
# 2    13830  187878.763989
# 3     9978  179789.672031
# 4     5005  169346.511515

# %%
reg.coef_
# Out:
# array([2.09997195])

# %%
reg.intercept_
# Out:
# 158836.15189687657
